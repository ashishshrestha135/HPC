# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
data = pd.read_csv('result.csv')
data1 = pd.read_csv('lr01.csv')
data2 = pd.read_csv('lr02.csv')
data3 = pd.read_csv('lr03.csv')
data4 = pd.read_csv('lr04.csv')

# %%
plt.scatter(data.x,data.y)
# plt.plot(data1.x,data1.y, c='k')
# plt.plot(data2.x,data2.y,c='r')
plt.plot(data4.x,data4.y, c='cyan')
plt.legend()
plt.show()
